# %% [markdown]
# <a href="https://colab.research.google.com/github/student-uzma/CSL701-CS10_Machine-Learning-Lab/blob/main/ML_1st_Exp_CS10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# NAME :Uzma Choudhary
# ROLL NO:CS10
# Batch : CS01

# %% [markdown]
# ##Aim: To familiarize students with Google Colab and Python libraries (NumPy, Pandas, Matplotlib and Seaborn) for loading, inspecting, cleaning manipulating and visualizing the Titanic dataset.

# %% [markdown]
# Phase 2: Environment Setup & Data Loading
#
# • Task 1: Import NumPy, Pandas, Matplotlib.pyplot and Seaborn.
#
# • Task 2: Load train.csv into a Pandas DataFrame using pd.read_csv().

# %%
# Task 1: Import the required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Task 2: Load train.csv into a Pandas DataFrame
df = pd.read_csv("Titanic-Dataset.csv")

# Display the first 5 rows to verify it loaded correctly
print(df.head())
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# Phase 3: Data Inspection
#
# • Task 3: Display first 10 rows using df.head(10).
#
# • Task 4: Display last 5 rows using df.tail(5).
#
# • Task 5: Check dataset dimensions using df.shape (Expected: 891 x 12).
#
# • Task 6: Display dataset information using df.info().
#
# • Task 7: Generate summary statistics using df.describe(); record mean, minimum and maximum values of Age and Fare.
#
# • Task 8: Identify missing values using df.isnull().sum().

# %%
# Task 3: Display first 10 rows
print("First 10 rows:")
print(df.head(10))

# Task 4: Display last 5 rows
print("\nLast 5 rows:")
print(df.tail(5))

# Task 5: Check dataset dimensions
print("\nDataset Shape:")
print(df.shape)      # Expected: (891, 12)

# Task 6: Display dataset information
print("\nDataset Information:")
df.info()

# Task 7: Generate summary statistics
print("\nSummary Statistics:")
print(df.describe())

# Display mean, minimum, and maximum values of Age and Fare
print("\nAge Statistics:")
print("Mean:", df["Age"].mean())
print("Minimum:", df["Age"].min())
print("Maximum:", df["Age"].max())

print("\nFare Statistics:")
print("Mean:", df["Fare"].mean())
print("Minimum:", df["Fare"].min())
print("Maximum:", df["Fare"].max())

# Task 8: Identify missing values
print("\nMissing Values in Each Column:")
print(df.isnull().sum())
# Out:
# First 10 rows:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %% [markdown]
# Phase 4: Data Manipulation & Cleaning
#
# • Task 9: Fill missing Age values with the median.
#
# • Task 10: Filter surviving passengers (Survived == 1).
#
# • Task 11: Convert Fare column to a NumPy array.
#
# • Task 12: Calculate maximum and average Fare using np.max() and np.mean().

# %%
# Task 9: Fill missing Age values with the median
df["Age"] = df["Age"].fillna(df["Age"].median())

# Check if missing Age values are filled
print("Missing values in Age:", df["Age"].isnull().sum())

# Task 10: Filter surviving passengers (Survived == 1)
survivors = df[df["Survived"] == 1]

print("\nFirst 5 surviving passengers:")
print(survivors.head())

# Task 11: Convert Fare column to a NumPy array
fare_array = df["Fare"].to_numpy()

print("\nFare NumPy Array:")
print(fare_array)

# Task 12: Calculate maximum and average Fare
max_fare = np.max(fare_array)
avg_fare = np.mean(fare_array)

print("\nMaximum Fare:", max_fare)
print("Average Fare:", avg_fare)
# Out:
# Missing values in Age: 0
#
# First 5 surviving passengers:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# ...

# %% [markdown]
# Phase 5: Data Visualization
#
# • Task 13: Plot histogram of Age.
#
# • Task 14: Plot bar chart of Survival Count.
#
# • Task 15: Plot scatter graph of Age vs Fare.

# %%
# Task 13: Plot histogram of Age
plt.figure(figsize=(8,5))
plt.hist(df["Age"], bins=20, color="skyblue", edgecolor="black")
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()

# Task 14: Plot bar chart of Survival Count
plt.figure(figsize=(6,4))
sns.countplot(x="Survived", data=df)
plt.title("Survival Count")
plt.xlabel("Survived (0 = No, 1 = Yes)")
plt.ylabel("Number of Passengers")
plt.show()

# Task 15: Plot scatter graph of Age vs Fare
plt.figure(figsize=(8,5))
plt.scatter(df["Age"], df["Fare"], color="green", alpha=0.6)
plt.title("Age vs Fare")
plt.xlabel("Age")
plt.ylabel("Fare")
plt.show()

# %% [markdown]
# Conclusion:
# The Titanic dataset was successfully loaded, inspected, cleaned, manipulated and visualized
# using Python libraries in Google Colab.
